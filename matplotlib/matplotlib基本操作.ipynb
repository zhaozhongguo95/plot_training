# %% [markdown]
# ## workflow

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,25,30]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,color='lightblue',linewidth=3)
ax.scatter([2,4,6],
          [5,15,25],
          color='darkgreen',
          marker='^')
ax.set_xlim(1,6.5)
plt.savefig('foo.pdf',dpi=300)
plt.show()

# %% [markdown]
# ## 数据准备

# %% [markdown]
# ### 1d

# %%
import numpy as np
x = np.linspace(0,10,100)
y = np.cos(x)
z= np.sin(x)

# %% [markdown]
# ### 2d or images

# %%
data = 2*np.random.random((10,10))
data2 = 3*np.random.random((10,10))
Y,X=np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2+Y
V = 1+X-Y**2
from matplotlib.cbook import get_sample_data
# img = np.load(get_sample_data('bivariate_normal.npy'))

# %% [markdown]
# ## 画图

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### figure

# %%
fig = plt.figure()
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %% [markdown]
# #### 坐标轴

# %%
fig.add_axes()
ax1 = fig.add_subplot(221)#221表示row-col-num
ax3=fig.add_subplot(212)
fig3,axes=plt.subplots(ncols=2,nrows=2)
fig4,axes2 = plt.subplots(ncols=3)

# %% [markdown]
# ## plotting routines

# %%
fig, ax = plt.subplots()
lines = ax.plot(x,y)
ax.scatter(x,y)
axes[0,0].bar([1,2,3],[3,4,5])
axes[1,0].barh([0.5,1,2.5],[0,1,2])
axes[1,1].axhline(0.45)
axes[0,1].axvline(0.65)
ax.fill(x,y,color='blue')
ax.fill_between(x,y,color='yellow')

# %%
fig,ax = plt.subplots()
# im = ax.imshow(img,cmap='gis_earth', interpolation='nearest',vmin=-2,vmax=2)

# %%
axes[0,1].arrow(0,0,0.5,0.5)
axes[1,1].quiver(y,z)
axes[0,1].streamplot(X,Y,U,V)

ax1.hist(y)
ax3.boxplot(y)
ax3.violinplot(z)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1e68d5c4748>],
#  'cbars': <matplotlib.collections.LineCollection at 0x1e68d6eaf28>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1e68d5c4400>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1e68d6eacc0>}

# %%
axes2[0].pcolor(data2)
axes2[0].pcolormesh(data)
CS = plt.contour(Y,X,U)
axes2[2].contourf(data1)
axes2[2] = ax.clabel(CS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-51256f6fba45> in <module>()
#       2 axes2[0].pcolormesh(data)
#       3 CS = plt.contour(Y,X,U)
# ----> 4 axes2[2].contourf(data1)
#       5 axes2[2] = ax.clabel(CS)
#
# NameError: name 'data1' is not defined

# %% [markdown]
# ## Customize plot

# %% [markdown]
# #### Colors, Color Bars & Color Maps

# %%
plt.plot(x,x,x,x**2,x,x**3)
ax.plot(x,y,alpha=0.4)
ax.plot(x,y,c='k')
fig.colorbar(im,orientation='horizontal')
im = ax.imshow(img,
              cmap='seismic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8fff170c3685> in <module>()
#       2 ax.plot(x,y,alpha=0.4)
#       3 ax.plot(x,y,c='k')
# ----> 4 fig.colorbar(im,orientation='horizontal')
#       5 im = ax.imshow(img,
#       6               cmap='seismic')
#
# NameError: name 'im' is not defined

# %% [markdown]
# #### Markers

# %%
fig, ax = plt.subplots()
ax.scatter(x,y,marker='.')
ax.plot(x,y,marker='o')

# %% [markdown]
# #### Linestyles

# %%
plt.plot(x,y,linewidth=4.0)
plt.plot(x,y,ls='solid')
plt.plot(x,y,ls='--')
plt.plot(x,y,'--',x*2,y**2,'-.')

# %% [markdown]
# #### Text & Annations

# %%
ax.text(1,-2.1,'Example Graph',style='italic')
ax.annotate("Sine",
            xy=(8,0),
            xycoords='data',
            xytext=(10.5,0),
            textcoords='data',
            arrowprops=dict(arrowstyle="->",
                          connectionstyle="arc3" ),)
# Out:
# Text(10.5, 0, 'Sine')

# %%
plt.title(r'$sigma_i=15$', fontsize=20)
# Out:
# Text(0.5, 1.0, '$sigma_i=15$')

# %% [markdown]
# #### Limits & Atoscalling

# %%
ax.margins(x=0.0,y=0.1)
ax.axis('equal')
ax.set(xlim=[0,10.5],ylim=[-1.5,1.5])
ax.set_xlim(0,10.5)
# Out:
# (0, 10.5)

# %%
fig3.subplots_adjust(wspace=0.5,
                     hspace=0.3,
                     left=0.125,
                     right=0.9,
                     top=0.9,
                     bottom=0.1)
fig.tight_layout()

# %%
#axis spines
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_position(('outward',10))
